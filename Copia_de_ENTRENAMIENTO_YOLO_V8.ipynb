# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-Jose-M-M/rutas-prueba/blob/prueba-v2/Copia_de_ENTRENAMIENTO_YOLO_V8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalacion de yolo v8
# Instala ultralytics:
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
# !yolo train model=yolov8n.pt data=daoi.yaml epochs=300 imgsz=640
#yolo task=segment mode=train epochs=100 data=data.yaml model=yolov8m-seg.pt imgsz=640 batch=5
# Resume an interrupted training
#!yolo train resume model="/content/runs/detect/train4/weights/last.pt"
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#!unzip "/content/drive/MyDrive/yourfolder/frames.zip" -d "/content/destino/upload/"
# !unzip "/content/d.zip" -d "/content/das/"
